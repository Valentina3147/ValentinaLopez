# %% [markdown]
# <a href="https://colab.research.google.com/github/Valentina3147/ValentinaLopez/blob/main/Semana2/Entregable_Taller_Forecasting_Ocupacion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Cargar dataset de ocupacion de sitios de parqueo
data = pd.read_csv('SJ.csv')
data.head()
# Out:
#       date  idCompany  numTrx
# 0  2022-08          1   68599
# 1  2022-09          1   86862
# 2  2022-10          1   99611
# 3  2022-11          1  109018
# 4  2022-12          1  115665

# %%
# Revisar cabecera y cola del dataset


print(data.head())
print(data.tail())
# Out:
#       date  idCompany  numTrx
# 0  2022-08          1   68599
# 1  2022-09          1   86862
# 2  2022-10          1   99611
# 3  2022-11          1  109018
# 4  2022-12          1  115665
#        date  idCompany  numTrx
# 13  2023-09          1  126851
# 14  2023-10          1  137539
# 15  2023-11          1  145327
# 16  2023-12          1  135537
# 17  2024-01          1  148111

# %%
# Formatear la columna de fecha como año y mes

data['date'] = pd.to_datetime(data['date'], format='%Y-%m')

data.head()
# Out:
#         date  idCompany  numTrx
# 0 2022-08-01          1   68599
# 1 2022-09-01          1   86862
# 2 2022-10-01          1   99611
# 3 2022-11-01          1  109018
# 4 2022-12-01          1  115665

# %%
# Verificar el nombre de los meses del dataset para comprobar que el formateo es correcto

data['date'].dt.month_name().unique()
data.head()
# Out:
#         date  idCompany  numTrx
# 0 2022-08-01          1   68599
# 1 2022-09-01          1   86862
# 2 2022-10-01          1   99611
# 3 2022-11-01          1  109018
# 4 2022-12-01          1  115665

# %%
# Contar el numero de datos del dataset

data.count()
# Out:
# date         18
# idCompany    18
# numTrx       18
# dtype: int64

# %%
# Obtener una estadistica descriptiva básica del dataset, verificar si hay algo anormal


data.describe()
# Out:
#                       date  idCompany         numTrx
# count                   18       18.0      18.000000
# mean   2023-04-16 18:40:00        1.0  120111.833333
# min    2022-08-01 00:00:00        1.0   68599.000000
# 25%    2022-12-08 18:00:00        1.0  110679.750000
# 50%    2023-04-16 00:00:00        1.0  125518.500000
# 75%    2023-08-24 06:00:00        1.0  135321.000000
# max    2024-01-01 00:00:00        1.0  148111.000000
# std                    NaN        0.0   20840.047288

# %%
# Revisar si el ldataset tiene datos nullos

data.isnull().sum()
# Out:
# date         0
# idCompany    0
# numTrx       0
# dtype: int64

# %%
# Establecer el campo fecha como index del dataframe

data.set_index('date', inplace=True)
data.head()
# Out:
#             idCompany  numTrx
# date
# 2022-08-01          1   68599
# 2022-09-01          1   86862
# 2022-10-01          1   99611
# 2022-11-01          1  109018
# 2022-12-01          1  115665

# %%
# Verificar nuevamente el head de la tabla y comprobar que el index ahora sea la fecha

data.head()
# Out:
#             idCompany  numTrx
# date
# 2022-08-01          1   68599
# 2022-09-01          1   86862
# 2022-10-01          1   99611
# 2022-11-01          1  109018
# 2022-12-01          1  115665

# %%
# Realizar una grafica de tendencia del numero de espacios ocupados en el tiempo

data.plot(figsize=(10,5))
plt.show()

# %%
data.head()
# Out:
#             idCompany  numTrx
# date
# 2022-08-01          1   68599
# 2022-09-01          1   86862
# 2022-10-01          1   99611
# 2022-11-01          1  109018
# 2022-12-01          1  115665

# %%
# Eliminar las columnas que no necesiten para realizar un sistema de prediccion de ocupacion de parqueo

data=data.drop(labels=['idCompany'],axis=1)

# %%
# Escalar entre -1 y 1 los datos de la variable a predecir


from sklearn.preprocessing import MinMaxScaler
scalar=MinMaxScaler(feature_range=(-1,1))

data_arr = scalar.fit_transform(data)

data_arr
# Out:
# array([[-1.        ],
#        [-0.5406228 ],
#        [-0.21994164],
#        [ 0.01667673],
#        [ 0.18387162],
#        [ 0.20920113],
#        [ 0.24748466],
#        [ 0.66198813],
#        [-0.18507898],
#        [ 0.53282523],
#        [ 0.40859241],
#        [ 0.45484958],
#        [ 0.74019016],
#        [ 0.46523795],
#        [ 0.73407788],
#        [ 0.92997283],
#        [ 0.6837207 ],
#        [ 1.        ]])

# %%
# Definir una ventana temporal adecuada para la prediccion y establecer las listas
# xtrain y ytrain para el entrenamiento

steps = 12
xtrain = []
ytrain = []

for i in range(len(data_arr)-steps):
    xtrain.append(data_arr[i:i+steps])
    ytrain.append(data_arr[i+steps])

# %%
# Convertir las listas en arrays de numpy


xtrain = np.array(xtrain)
ytrain = np.array(ytrain)

# %%
# Verificar el shape de los datos de entrenamiento (variable independiente y dependiente)


print(xtrain.shape,ytrain.shape)
# Out:
# (6, 12, 1) (6, 1)

# %%
# Construir un modelo LSTM para realizar la predicción que tenga la siguiente arquitectura

# Una capa LSTM de 256 neuronas con activación relu
# Una capa LSTM de 256 neuronas con activación relu
# Una capa LSTM de 128 neuronas con activación relu
# Una capa LSTM de 64 neuronas con activación relu
# Una capa LSTM de 32 neuronas con activación relu
# Una capa LSTM de 16 neuronas con activación relu (esta seria la ultima capa LSTM)
# Agregar operaciones de Dropout de 7% despues de cada capa LSTM
# Agregar en la etapa final una red densa con dos capas con 64 neuronas y 32 neuronas
# Finalmente agregar una capa densa de salida
# Imprimir el summary del  modelo


from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM,Dense,Dropout


model = Sequential()
model.add(LSTM(units=256,return_sequences=True,activation='relu',input_shape=(20,1)))

#dropout elimina neuronas al azar
model.add(Dropout(0.07))


model.add(LSTM(units=128,return_sequences=True,activation='relu'))
model.add(Dropout(0.07))
model.add(LSTM(units=64,return_sequences=True,activation='relu'))
model.add(Dropout(0.07))
model.add(LSTM(units=32,return_sequences=True,activation='relu'))
model.add(Dropout(0.07))
model.add(LSTM(units=16,return_sequences=False,activation='relu'))
model.add(Dropout(0.07))

model.add(Dense(64))
model.add(Dense(32))
model.add(Dense(1))

model.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 20, 256)             │         264,192 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 20, 256)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 20, 128)             │         197,120 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 20, 128)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_2 (LSTM)                        │ (None, 20, 64)              │          49,408 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 20, 64)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_3 (LSTM)                        │ (None, 20, 32)              │          12,416 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 20, 32)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_4 (LSTM)                        │ (None, 16)                  │           3,136 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 16)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 64)                  │           1,088 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 529,473 (2.02 MB)
#  Trainable params: 529,473 (2.02 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compilar el modelo con una funcion de error mse y un optimizador adam

model.compile(optimizer='adam',loss='mse')

# %%
# Entrenar el modelo durante 100 epocas
# Usar el 10% de los datos de entrenamiento para validacion
# Usar un batch size de 16


history=model.fit(xtrain,ytrain,epochs=100,validation_split=0.1,batch_size=16,verbose=1)
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.5271 - val_loss: 0.9586
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.4984 - val_loss: 0.9141
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.4681 - val_loss: 0.8670
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 0.4356 - val_loss: 0.8167
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 0.4026 - val_loss: 0.7626
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 0.3635 - val_loss: 0.7039
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - loss: 0.3252 - val_loss: 0.6397
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - loss: 0.2840 - val_loss: 0.5687
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.2361 - val_loss: 0.4895
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.1952 - val_loss: 0.3996
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.1428 - val_loss: 0.2969
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 0.0883 - val_loss: 0.1804
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 0.0462 - val_loss: 0.0599
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0260 - val_loss: 0.0018
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - loss: 0.1086 - val_loss: 0.0039
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0700 - val_loss: 0.0170
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 0.0371 - val_loss: 0.0380
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.0430 - val_loss: 0.0616
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0108 - val_loss: 0.0821
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - loss: 0.0226 - val_loss: 0.0985
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step - loss: 0.0254 - val_loss: 0.1096
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - loss: 0.0271 - val_loss: 0.1170
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - loss: 0.0278 - val_loss: 0.1203
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - loss: 0.0322 - val_loss: 0.1202
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step - loss: 0.0291 - val_loss: 0.1179
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 393ms/step - loss: 0.0261 - val_loss: 0.1132
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 534ms/step - loss: 0.0244 - val_loss: 0.1074
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step - loss: 0.0256 - val_loss: 0.1008
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 615ms/step - loss: 0.0232 - val_loss: 0.0937
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step - loss: 0.0196 - val_loss: 0.0869
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 508ms/step - loss: 0.0216 - val_loss: 0.0803
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step - loss: 0.0191 - val_loss: 0.0742
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - loss: 0.0114 - val_loss: 0.0683
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - loss: 0.0247 - val_loss: 0.0635
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - loss: 0.0265 - val_loss: 0.0600
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - loss: 0.0198 - val_loss: 0.0574
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - loss: 0.0231 - val_loss: 0.0562
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - loss: 0.0171 - val_loss: 0.0553
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step - loss: 0.0348 - val_loss: 0.0550
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - loss: 0.0235 - val_loss: 0.0560
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - loss: 0.0204 - val_loss: 0.0576
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 0.0224 - val_loss: 0.0601
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - loss: 0.0182 - val_loss: 0.0620
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - loss: 0.0251 - val_loss: 0.0641
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - loss: 0.0212 - val_loss: 0.0668
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step - loss: 0.0212 - val_loss: 0.0694
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - loss: 0.0172 - val_loss: 0.0719
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - loss: 0.0223 - val_loss: 0.0745
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - loss: 0.0264 - val_loss: 0.0764
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step - loss: 0.0214 - val_loss: 0.0782
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 542ms/step - loss: 0.0244 - val_loss: 0.0797
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - loss: 0.0230 - val_loss: 0.0811
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - loss: 0.0247 - val_loss: 0.0822
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 632ms/step - loss: 0.0296 - val_loss: 0.0825
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - loss: 0.0150 - val_loss: 0.0822
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - loss: 0.0339 - val_loss: 0.0811
# Epoch 57/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - loss: 0.0229 - val_loss: 0.0799
# Epoch 58/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - loss: 0.0227 - val_loss: 0.0789
# Epoch 59/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - loss: 0.0227 - val_loss: 0.0779
# Epoch 60/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step - loss: 0.0231 - val_loss: 0.0769
# Epoch 61/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step - loss: 0.0221 - val_loss: 0.0758
# Epoch 62/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step - loss: 0.0244 - val_loss: 0.0742
# Epoch 63/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 519ms/step - loss: 0.0218 - val_loss: 0.0723
# Epoch 64/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 0.0242 - val_loss: 0.0705
# Epoch 65/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 778ms/step - loss: 0.0195 - val_loss: 0.0681
# Epoch 66/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 530ms/step - loss: 0.0189 - val_loss: 0.0660
# Epoch 67/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 766ms/step - loss: 0.0257 - val_loss: 0.0645
# Epoch 68/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 728ms/step - loss: 0.0209 - val_loss: 0.0631
# Epoch 69/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - loss: 0.0213 - val_loss: 0.0619
# Epoch 70/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - loss: 0.0229 - val_loss: 0.0612
# Epoch 71/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.0238 - val_loss: 0.0610
# Epoch 72/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0165 - val_loss: 0.0603
# Epoch 73/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.0256 - val_loss: 0.0596
# Epoch 74/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - loss: 0.0219 - val_loss: 0.0600
# Epoch 75/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0167 - val_loss: 0.0596
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0208 - val_loss: 0.0601
# Epoch 77/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0209 - val_loss: 0.0602
# Epoch 78/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 0.0199 - val_loss: 0.0600
# Epoch 79/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0219 - val_loss: 0.0598
# Epoch 80/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - loss: 0.0224 - val_loss: 0.0593
# Epoch 81/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 0.0170 - val_loss: 0.0576
# Epoch 82/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - loss: 0.0163 - val_loss: 0.0553
# Epoch 83/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 0.0198 - val_loss: 0.0539
# Epoch 84/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0183 - val_loss: 0.0526
# Epoch 85/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 0.0216 - val_loss: 0.0521
# Epoch 86/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.0190 - val_loss: 0.0506
# Epoch 87/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - loss: 0.0244 - val_loss: 0.0506
# Epoch 88/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - loss: 0.0211 - val_loss: 0.0510
# Epoch 89/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.0225 - val_loss: 0.0514
# Epoch 90/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.0249 - val_loss: 0.0515
# Epoch 91/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 0.0219 - val_loss: 0.0512
# Epoch 92/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 0.0241 - val_loss: 0.0502
# Epoch 93/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 0.0239 - val_loss: 0.0502
# Epoch 94/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - loss: 0.0190 - val_loss: 0.0492
# Epoch 95/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 0.0216 - val_loss: 0.0483
# Epoch 96/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 0.0180 - val_loss: 0.0468
# Epoch 97/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0194 - val_loss: 0.0448
# Epoch 98/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - loss: 0.0143 - val_loss: 0.0411
# Epoch 99/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 0.0288 - val_loss: 0.0376
# Epoch 100/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.0201 - val_loss: 0.0352

# %%
# Grafifcar el loss y loss de validacion para verificar que no haya overfitting
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['train loss','val loss'])
plt.show()

# %%
# Guardar el modelo y salvarlo en disco

model.save('taller.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# Tome N registros historicos de su dataset y realice la predicción de ocupación para un mes particular
import numpy as np

n = 2


data1 = data_arr[-n:]

data1 = data1.reshape((1, n, 1))

ypred = model.predict(data1)

ypred_original = scalar.inverse_transform(ypred)


print(ypred_original[0][0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 974ms/step
# 128740.48

# %%
# Proponga una arquitectura que permita recibir como parametros de entrada no solo los historicos de la
# serie temporal sino tambien información adicional relevante como por ejemplo el mes para el cual se
# realiza la predicción, o el número de dias festivos del mes de predicción
